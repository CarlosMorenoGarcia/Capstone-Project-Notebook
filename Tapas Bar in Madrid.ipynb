# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#First find the latitude & longitude of Madrid city center
address = 'Madrid'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Madrid are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Madrid are 40.4167047, -3.7035825.

# %%
# create map of Madrid using latitude and longitude values

map_Madrid = folium.Map(location=[latitude, longitude], zoom_start=14)

map_Madrid
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json, requests
url = 'https://api.foursquare.com/v2/venues/explore'

params = dict(
client_id='IOS3IKXAHUENUKBVWDXVE2KOFXGZ2HIL51AMJNX2XYYPD431',
client_secret='ZRUESVFJTPKI1STMXSZTCXBSK3N05QEM0K4JIPW0QKJFJKCL',
v='20180323',
ll='40.4167047, -3.7035825',
query='bar',
limit=10
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)
data
# Out:
# {'meta': {'code': 200, 'requestId': '5ebd489c9da7ee001b0b85f2'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 600,
#   'headerLocation': 'Sol',
#   'headerFullLocation': 'Sol, Madrid',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'bar',
#   'totalResults': 347,
#   'suggestedBounds': {'ne': {'lat': 40.41962339613909,
#     'lng': -3.6989180966218145},
#    'sw': {'lat': 40.411215417563966, 'lng': -3.7093973287322948}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc7603c6501c9b61e4f3e29',
#        'name': 'Yambala',
#        'contact': {},
#        'location': {'address': 'C. Coloreros',
#         'lat': 40.41664556425945,
# ...

# %%
df_data = pd.DataFrame(data[0])
df_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-bb1d20ffd2a2> in <module>
# ----> 1 df_data = pd.DataFrame(data[0])
#       2 df_data
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466                                    dtype=values.dtype, copy=False)
#     467             else:
# --> 468                 raise ValueError('DataFrame constructor not properly called!')
#     469
#     470         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
# define the dataframe columns
column_names = ['postalCode', 'name', 'Latitude', 'Longitude'] 

# instantiate the dataframe
bares = pd.DataFrame(columns=column_names)

bares
# Out:
# Empty DataFrame
# Columns: [postalCode, name, Latitude, Longitude]
# Index: []

# %%
for data in bares:
    postalCode = bares_name = data['properties']['postalCode'] 
    bares_name = data['properties']['name']
        
    bares_latlon = data['geometry']['coordinates']
    bares_lat = neighborhood_latlon[1]
    bares_lon = neighborhood_latlon[0]
    
    bares = bares.append({'postalCode': postalCode,
                                          'Name': bares_name,
                                          'Latitude': bares_lat,
                                          'Longitude': bares_lon}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-9e5fe22dd365> in <module>
#       1 for data in bares:
# ----> 2     postalCode = bares_name = data['properties']['postalCode']
#       3     bares_distance = data['properties']['distance']
#       4
#       5     bares_latlon = data['geometry']['coordinates']
#
# TypeError: string indices must be integers

# %%
#!pip install folium

import folium

# %%
map_Madrid = folium.Map(location=Madrid_center, zoom_start=10)
folium.Marker(Madrid_center, popup='Puerta del Sol').add_to(map_Madrid)
for lat, lon in zip(latitudes, longitudes):
    #folium.CircleMarker([lat, lon], radius=3, color='blue', fill=True, fill_color='blue', fill_opacity=2).add_to(map_madrid) 
    folium.Circle([lat, lon], radius=300, color='blue', fill=False).add_to(map_berlin)
    #folium.Marker([lat, lon]).add_to(map_Madrid)
map_Madrid
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-9dc39c2b122c> in <module>
# ----> 1 map_Madrid = folium.Map(location=Madrid_center, zoom_start=10)
#       2 folium.Marker(Madrid_center, popup='Puerta del Sol').add_to(map_Madrid)
#       3 for lat, lon in zip(latitudes, longitudes):
#       4     #folium.CircleMarker([lat, lon], radius=3, color='blue', fill=True, fill_color='blue', fill_opacity=2).add_to(map_madrid)
#       5     folium.Circle([lat, lon], radius=300, color='blue', fill=False).add_to(map_berlin)
#
# ...
